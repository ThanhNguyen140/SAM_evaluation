# %% [markdown]
# ## Pipeline 1:
# - Negative with positive prompts
# - Number of prompts for each class: 1

# %%
import sys
sys.path.append("..")
from functions.pipeline import *

# %%
df = analyze()
# Out:
# Input path: /home/stud/nguyenp0/database/preprocess
# Output path: /home/stud/nguyenp0/database/results
# Name of pipeline: pipeline1
# Test of only positive prompts [y/n]: n
# Number of prompts for class 1: 1
# Number of prompts for class 2: 1
# Number of prompts for class 3: 1
# patient087_frame10_gt.npy.gz
# patient087_frame01_gt.npy.gz
# patient147_frame01_gt.npy.gz
# patient147_frame09_gt.npy.gz
# patient113_frame01_gt.npy.gz
# patient113_frame08_gt.npy.gz
# patient023_frame01_gt.npy.gz
# patient023_frame09_gt.npy.gz
# patient083_frame01_gt.npy.gz
# patient083_frame08_gt.npy.gz
# patient024_frame01_gt.npy.gz
# patient024_frame09_gt.npy.gz
# patient077_frame09_gt.npy.gz
# patient077_frame01_gt.npy.gz
# patient028_frame01_gt.npy.gz
# patient028_frame09_gt.npy.gz
# patient072_frame11_gt.npy.gz
# patient072_frame01_gt.npy.gz
# patient070_frame01_gt.npy.gz
# patient070_frame10_gt.npy.gz
# ...

# %%
df
# Out:
#                          files  accuracy_1  iou_1  dice_1  accuracy_2  iou_2  \
# 0    patient087_frame10.npy.gz       0.856  0.777   0.870       0.476  0.395
# 1    patient087_frame01.npy.gz       0.910  0.841   0.912       0.369  0.268
# 2    patient147_frame01.npy.gz       0.970  0.909   0.950       0.383  0.304
# 3    patient147_frame09.npy.gz       0.934  0.880   0.930       0.715  0.642
# 4    patient113_frame01.npy.gz       0.874  0.775   0.855       0.396  0.290
# ..                         ...         ...    ...     ...         ...    ...
# 295  patient130_frame11.npy.gz       0.826  0.697   0.812       0.743  0.616
# 296  patient132_frame15.npy.gz       0.947  0.599   0.704       0.371  0.281
# 297  patient132_frame01.npy.gz       0.954  0.728   0.829       0.290  0.237
# 298  patient060_frame14.npy.gz       0.957  0.461   0.584       0.275  0.231
# 299  patient060_frame01.npy.gz       0.981  0.644   0.739       0.302  0.217
#
#      dice_2  accuracy_3  iou_3  dice_3
# ...

# %%
df.describe()
# Out:
#        accuracy_1       iou_1      dice_1  accuracy_2       iou_2      dice_2  \
# count   300.00000  300.000000  300.000000  300.000000  300.000000  300.000000
# mean      0.87439    0.643333    0.744693    0.423460    0.346707    0.471640
# std       0.07412    0.159167    0.144259    0.147675    0.136757    0.143938
# min       0.54000    0.134000    0.216000    0.131000    0.090000    0.156000
# 25%       0.83175    0.539750    0.653750    0.307750    0.241750    0.367500
# 50%       0.88700    0.680000    0.788500    0.407500    0.329500    0.459000
# 75%       0.93200    0.766250    0.855250    0.516750    0.432500    0.570000
# max       1.00000    0.909000    0.950000    0.809000    0.736000    0.835000
#
#        accuracy_3       iou_3      dice_3
# count  300.000000  300.000000  300.000000
# mean     0.799537    0.690743    0.789323
# std      0.092393    0.132843    0.113572
# min      0.552000    0.258000    0.379000
# 25%      0.730250    0.600750    0.723750
# ...
