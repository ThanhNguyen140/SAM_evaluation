# %%
import pandas as pd
import sys
sys.path.append('..')
from functions.pipeline import *

# %%
file_list = ["pos_0100.csv","pos_0500.csv","pos_1000.csv","neg_and_pos_0101.csv","pos_and_neg_0501.csv","pos_and_neg_0503.csv","pos_1003.csv","pos_1005.csv","neg_pos_mixed.csv"]
path = "../ACDC/results"
df_list = []
for file in file_list:
    df = pd.read_csv(os.path.join(path,file))
    df_list.append(df)

# %%
def get_class_list(class_num,ground_truth):
    array1 = np.any(ground_truth == class_num, axis = 1)
    array2 = np.any(array1 == True, axis = 1)
    class_indices = np.where(array2 == True)
    indices = list(class_indices[0])
    return indices

# %%
ground_truth = gzip_file("../ACDC/ground_truth.npy.gz","r")
class_indices = {}
for c in [1,2,3]:
    class_indices[c] = get_class_list(c,ground_truth)

# %%
df_list[3].head()
# Out:
#    image_id  f_points_class_1  f_points_class_2  f_points_class_3  \
# 0         0                 5                 5                 5
# 1         0                 5                 5                 5
# 2         0                 5                 5                 5
# 3         0                 5                 5                 5
# 4         0                 5                 5                 5
#
#    b_points_class_1  b_points_class_2  b_points_class_3  dice_class_1  \
# 0                 1                 1                 1         0.882
# 1                 1                 1                 1         0.929
# 2                 1                 1                 1         0.941
# 3                 1                 1                 1         0.912
# 4                 1                 1                 1         0.935
#
#    dice_class_2  dice_class_3  IOU_class_1  IOU_class_2  IOU_class_3  \
# 0         0.783         0.928        0.789        0.644        0.866
# ...

# %%
def result_class(class_num:int,df_list:list,indices:list):
    c = class_num
    dct = {"image_id":indices}
    for i in range(1,10):
        dct[f"mean_dice_{i}"] = []
        dct[f"mean_iou_{i}"] = []
        dct[f"mean_accuracy_{i}"] = []
        dct[f"std_dice_{i}"] = []
        dct[f"std_iou_{i}"] = []
        dct[f"std_accuracy_{i}"] = []
    for i,df in enumerate(df_list):
        for idx in indices:
            t = df[df.image_id == idx][[f"dice_class_{c}",f"IOU_class_{c}",f"accuracy_class_{c}"]]
            mean_scores = t.mean().to_list()
            dct[f"mean_dice_{i+1}"].append(mean_scores[0])
            dct[f"mean_iou_{i+1}"].append(mean_scores[1])
            dct[f"mean_accuracy_{i+1}"].append(mean_scores[2])

            std_scores = t.std().to_list()
            dct[f"std_dice_{i+1}"].append(std_scores[0])
            dct[f"std_iou_{i+1}"].append(std_scores[1])
            dct[f"std_accuracy_{i+1}"].append(std_scores[2])
    
    result_df = pd.DataFrame(dct)
    return result_df

# %%
2841 in class_indices[3]
# Out:
# False

# %%
t = df[df.image_id == 0]

# %%
t.mean().to_list()
# Out:
# [0.0,
#  10.0,
#  10.0,
#  10.0,
#  5.0,
#  5.0,
#  5.0,
#  0.9442999999999999,
#  0.7846199999999999,
#  0.9494799999999999,
#  0.8947000000000002,
#  0.6480799999999999,
#  0.9041400000000002,
#  0.9965999999999999,
#  0.99346,
#  0.99736]

# %%
class_1 = result_class(1,df_list,class_indices[1])
class_2 = result_class(2,df_list,class_indices[2])
class_3 = result_class(3,df_list,class_indices[3])

# %%
class_1.head()
# Out:
#    image_id  mean_dice_1  mean_iou_1  mean_accuracy_1  std_dice_1  std_iou_1  \
# 0         0      0.81394     0.68932          0.98702    0.051408   0.070274
# 1         1      0.54924     0.42570          0.93230    0.265393   0.263662
# 2         2      0.53566     0.37524          0.96370    0.123331   0.113893
# 3         3      0.17468     0.11528          0.68836    0.216670   0.169757
# 4         4      0.46246     0.31850          0.96304    0.183062   0.154451
#
#    std_accuracy_1  mean_dice_2  mean_iou_2  mean_accuracy_2  ...  \
# 0        0.004706      0.70424     0.58450          0.98586  ...
# 1        0.063000      0.86972     0.77384          0.99272  ...
# 2        0.020428      0.70108     0.56498          0.98830  ...
# 3        0.262725      0.55382     0.38406          0.97814  ...
# 4        0.044799      0.64538     0.48212          0.98858  ...
#
#    mean_accuracy_8  std_dice_8  std_iou_8  std_accuracy_8  mean_dice_9  \
# ...

# %%
class_2.head()
# Out:
#    image_id  mean_dice_1  mean_iou_1  mean_accuracy_1  std_dice_1  std_iou_1  \
# 0         0      0.41948     0.26774          0.96604    0.074327   0.051560
# 1         1      0.18788     0.10922          0.86760    0.120388   0.084251
# 2         2      0.09420     0.05390          0.91974    0.119181   0.074865
# 3         3      0.01590     0.00814          0.66338    0.018748   0.009602
# 4         4      0.22820     0.14214          0.83358    0.182991   0.133184
#
#    std_accuracy_1  mean_dice_2  mean_iou_2  mean_accuracy_2  ...  \
# 0        0.004798      0.59722     0.43904          0.97892  ...
# 1        0.072451      0.72682     0.57636          0.98704  ...
# 2        0.049749      0.41058     0.26094          0.96124  ...
# 3        0.270822      0.45018     0.29456          0.97938  ...
# 4        0.191005      0.66168     0.49924          0.98622  ...
#
#    mean_accuracy_8  std_dice_8  std_iou_8  std_accuracy_8  mean_dice_9  \
# ...

# %%
class_3.head()
# Out:
#    image_id  mean_dice_1  mean_iou_1  mean_accuracy_1  std_dice_1  std_iou_1  \
# 0         0      0.07702     0.06024          0.97464    0.220973   0.180673
# 1         1      0.95918     0.92650          0.99810    0.060170   0.086672
# 2         2      0.82828     0.77820          0.99260    0.293583   0.292010
# 3         3      0.56174     0.47244          0.98408    0.363271   0.332522
# 4         4      0.94880     0.90818          0.99758    0.061367   0.096130
#
#    std_accuracy_1  mean_dice_2  mean_iou_2  mean_accuracy_2  ...  \
# 0        0.004894      0.84400     0.74244          0.99316  ...
# 1        0.002460      0.87946     0.79970          0.99434  ...
# 2        0.009783      0.12416     0.08628          0.97150  ...
# 3        0.009998      0.85222     0.74990          0.99250  ...
# 4        0.002556      0.87568     0.78744          0.99428  ...
#
#    mean_accuracy_8  std_dice_8  std_iou_8  std_accuracy_8  mean_dice_9  \
# ...

# %%
fig, ax = plt.subplots(2,1,figsize = (15,10))
ax[0].boxplot([class_1[f"mean_dice_{i+1}"] for i in range(9)])
ax[0].set_xticklabels([label.replace(".csv","") for label in file_list], rotation = 90)
ax[0].set_title("Dice score class 1")
ax[1].boxplot([class_1[f"mean_iou_{i+1}"] for i in range(9)])
ax[1].set_xticklabels([label.replace(".csv","") for label in file_list], rotation = 90)
ax[1].set_title("IOU score class 1")
fig.tight_layout()

# %%
fig, ax = plt.subplots(2,1,figsize = (15,10))
ax[0].boxplot([class_2[f"mean_dice_{i+1}"] for i in range(9)])
ax[0].set_xticklabels([label.replace(".csv","") for label in file_list], rotation = 90)
ax[0].set_title("Dice score class 2")
ax[1].boxplot([class_2[f"mean_iou_{i+1}"] for i in range(9)])
ax[1].set_xticklabels([label.replace(".csv","") for label in file_list], rotation = 90)
ax[1].set_title("IOU score class 2")
fig.tight_layout()

# %%
fig, ax = plt.subplots(2,1,figsize = (15,10))
colors = ["red","green","blue","yellow","black","purple","brown","violet","orange"]
ax[0].boxplot([class_3[f"mean_dice_{i+1}"] for i in range(9)])
ax[0].set_xticklabels([label.replace(".csv","") for label in file_list], rotation = 90)
ax[0].set_title("Dice score class 3")
ax[1].boxplot([class_3[f"mean_iou_{i+1}"] for i in range(9)])
ax[1].set_xticklabels([label.replace(".csv","") for label in file_list], rotation = 90)
ax[1].set_title("IOU score class 3")
fig.tight_layout()
